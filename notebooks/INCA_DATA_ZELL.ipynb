# %%
## open file

# %%
import xarray as xr

# Path to your INCA file
path = "/storage/homefs/ge24z347/Liestal_event/Data_forprocess/INCA_DATA_ZELL/RR_INCA_202205051600.nc"

# Open file
ds = xr.open_dataset(path)
ds
# Out:
# <xarray.Dataset> Size: 71MB
# Dimensions:       (time: 37, y: 640, x: 710)
# Coordinates:
#   * time          (time) datetime64[ns] 296B 2022-05-05T16:00:00 ... 2022-05-...
#   * x             (x) float32 3kB 2.256e+06 2.256e+06 ... 2.964e+06 2.964e+06
#   * y             (y) float32 3kB 8.405e+05 8.415e+05 ... 1.478e+06 1.48e+06
#     longitude     (y, x) float32 2MB ...
#     latitude      (y, x) float32 2MB ...
# Data variables:
#     RR            (time, y, x) float32 67MB ...
#     grid_mapping  float32 4B ...
# Attributes:
#     source:        model: inca-1,product_category: determinist, version: 3.3.4
#     bounding_box:  [2.696701032898132, 43.62376638537423, 12.455025932877652,...
#     grid_mapping:  {"epsg_code": "EPSG:2056", "long_name": "Swiss coordinate ...

# %%
import xarray as xr

# Path to your INCA file
Zell_2m = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Zell_2m/Zell_2m.nc"
# Open file
Zell_2m_nc = xr.open_dataset(Zell_2m)
Zell_2m_nc
# Out:
# <xarray.Dataset> Size: 1kB
# Dimensions:         (time: 11, y: 3, x: 5)
# Coordinates:
#   * time            (time) float64 88B 0.0 1.0 2.0 3.0 4.0 ... 7.0 8.0 9.0 10.0
#   * y               (y) float64 24B 1.256e+06 1.256e+06 1.258e+06
#   * x               (x) float64 40B 2.702e+06 2.704e+06 ... 2.706e+06 2.706e+06
# Data variables:
#     rainfall_depth  (time, y, x) float64 1kB ...

# %%
import xarray as xr

# Path to your INCA file
Cosmo = "/storage/homefs/ge24z347/Liestal_event/Data_forprocess/COSMO/cosmo1e_2022-05-05T12.nc"
# Open file
Cosmo_Zell = xr.open_dataset(Cosmo)
Cosmo_Zell
# Out:
# /tmp/ipykernel_1308726/3039056343.py:6: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   Cosmo_Zell = xr.open_dataset(Cosmo)
# <xarray.Dataset> Size: 680MB
# Dimensions:                  (forecast_reference_time: 1, lead_time: 34,
#                               realization: 11, y: 640, x: 710)
# Coordinates:
#   * lead_time                (lead_time) timedelta64[ns] 272B 00:00:00 ... 1 ...
#   * forecast_reference_time  (forecast_reference_time) datetime64[ns] 8B 2022...
#   * realization              (realization) float64 88B 0.0 1.0 2.0 ... 9.0 10.0
#     time                     (forecast_reference_time, lead_time) datetime64[ns] 272B ...
#   * y                        (y) int64 5kB 840500 841500 ... 1478500 1479500
#   * x                        (x) int64 6kB 2255500 2256500 ... 2963500 2964500
# Data variables:
# ...

# %%
import xarray as xr

# Path to your INCA file
Combiprecip_Zell = "/storage/homefs/ge24z347/Liestal_event/Data_forprocess/Combiprecip/CPC_00060_H_20220502000000_20220508230000.nc"
# Open file
Zell_2m_Combi = xr.open_dataset(Combiprecip_Zell)
Zell_2m_Combi
# Out:
# <xarray.Dataset> Size: 305MB
# Dimensions:       (REFERENCE_TS: 168, y: 640, x: 710)
# Coordinates:
#   * REFERENCE_TS  (REFERENCE_TS) datetime64[ns] 1kB 2022-05-02 ... 2022-05-08...
#   * y             (y) float64 5kB 1.48e+06 1.478e+06 ... 8.415e+05 8.405e+05
#   * x             (x) float64 6kB 2.256e+06 2.256e+06 ... 2.964e+06 2.964e+06
# Data variables:
#     CPC           (REFERENCE_TS, y, x) float32 305MB ...
# Attributes:
#     Conventions:      CF-1.6
#     Source_Software:  FME

# %%
## cropped INCA DATA

import xarray as xr

# Path to your INCA file
INCA_Zell = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Zell_2m/Zell_INCA_2m_202205051600.nc"
# Open file
Zell_2m_INCA = xr.open_dataset(INCA_Zell)
Zell_2m_INCA
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:         (time: 37, x: 5, y: 3)
# Coordinates:
#   * time            (time) float64 296B 0.0 0.1667 0.3333 ... 5.667 5.833 6.0
#   * x               (x) float32 20B 2.702e+06 2.704e+06 ... 2.706e+06 2.706e+06
#   * y               (y) float32 12B 1.256e+06 1.256e+06 1.258e+06
# Data variables:
#     rainfall_depth  (time, y, x) float32 2kB ...
# Attributes:
#     description:  Cropped deterministic INCA rainfall (10-min, time in hours)
#     history:      Created on 2025-11-27
#     source:       INCA deterministic forecast cropped to DEM/bounds footprint

# %%
Zell_2m_INCA ["time"].values
# Out:
# array([0.        , 0.16666667, 0.33333333, 0.5       , 0.66666667,
#        0.83333333, 1.        , 1.16666667, 1.33333333, 1.5       ,
#        1.66666667, 1.83333333, 2.        , 2.16666667, 2.33333333,
#        2.5       , 2.66666667, 2.83333333, 3.        , 3.16666667,
#        3.33333333, 3.5       , 3.66666667, 3.83333333, 4.        ,
#        4.16666667, 4.33333333, 4.5       , 4.66666667, 4.83333333,
#        5.        , 5.16666667, 5.33333333, 5.5       , 5.66666667,
#        5.83333333, 6.        ])
