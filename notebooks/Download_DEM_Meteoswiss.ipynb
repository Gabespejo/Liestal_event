# %%
import os
import glob
from osgeo import gdal  # 
import pandas as pd
import requests
import os, sys
sys.path.insert(0, "/storage/homefs/ge24z347/Zell_event/src")
from DEM_processing import download_from_csvfile, extract_relevant_rasters, merge_dem_rasters,extract_rasters_near_campground

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/DEM/DEM_Hilterfingen/"  # Folder containing multiple .tif DEMs
output_file = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Hilterfingen_2m/Hilterfingen_2m_fulldomain.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Merging with bounds:
#   None
# Pixel size: 2.0 x 2.0
# /storage/homefs/ge24z347/mambaforge/envs/env_py311/lib/python3.11/site-packages/osgeo/gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
#  Merged DEM saved: /storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Hilterfingen_2m/Hilterfingen_2m_fulldomain.tif

# %%
### Agno

# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/DEM/DEM_2m_Agno/Agno_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/DEM/DEM_2m_Agno/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2714-1108/swissalti3d_2022_2714-1108_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2727-1105/swissalti3d_2022_2727-1105_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2718-1084/swissalti3d_2022_2718-1084_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2707-1104/swissalti3d_2022_2707-1104_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2714-1088/swissalti3d_2022_2714-1088_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2727-1104/swissalti3d_2022_2727-1104_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2723-1118/swissalti3d_2022_2723-1118_2_2056_5728.tif'
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/DEM/DEM_2m_Agno/"  # Folder containing multiple .tif DEMs
output_file = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Agno_2m/Agno_2m.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Merging with bounds:
#   None
# Pixel size: 2.0 x 2.0
#  Merged DEM saved: /storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Agno_2m/Agno_2m.tif

# %%
### Bellinzona 

# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/DEM/DEM_2m_Bellinzona/Bellinzona_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/DEM/DEM_2m_Bellinzona/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2023_2731-1150/swissalti3d_2023_2731-1150_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2023_2744-1162/swissalti3d_2023_2744-1162_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2717-1158/swissalti3d_2022_2717-1158_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2023_2726-1127/swissalti3d_2023_2726-1127_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2710-1158/swissalti3d_2022_2710-1158_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2023_2728-1153/swissalti3d_2023_2728-1153_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2023_2733-1147/swissalti3d_2023_2733-1147_2_2056_5728.tif'
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/DEM/DEM_2m_Bellinzona/"  # Folder containing multiple .tif DEMs
output_file = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Bellinzona_2m/Bellinzona_2m_fulldomain.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Merging with bounds:
#   None
# Pixel size: 2.0 x 2.0
# /storage/homefs/ge24z347/mambaforge/envs/env_py311/lib/python3.11/site-packages/osgeo/gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
#  Merged DEM saved: /storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Bellinzona_2m/Bellinzona_2m_fulldomain.tif

# %%
#### LIESTAL

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/LIESTAL_DEM_2M/Liestal_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/LIESTAL_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2615-1246/swissalti3d_2019_2615-1246_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2636-1255/swissalti3d_2019_2636-1255_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2626-1248/swissalti3d_2019_2626-1248_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2631-1244/swissalti3d_2019_2631-1244_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2615-1226/swissalti3d_2019_2615-1226_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2624-1255/swissalti3d_2019_2624-1255_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2603-1228/swissalti3d_2019_2603-1228_2_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
from DEM_processing import extract_relevant_rasters_netCDF_aligned
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/LIESTAL_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/LIESTAL_DEM_2M/LIESTAL"
location_id = 2  # The ID of the target location from the CSV


extract_relevant_rasters_netCDF_aligned(
    location_csv,
    dem_folder,
    output_folder,
    location_id,
    square_extent=10000,  # Default 10 km × 10 km, user can change to 20000 etc.
    netcdf_grid_step=1000,  # Alignment to 1 km NetCDF
    crs="EPSG:2056"
)
# Out:
# 📏 Snapped NetCDF-aligned extent: 10000.0m × 10000.0m
# 📍 Bounding box: X: 2616000.0 → 2626000.0, Y: 1254000.0 → 1264000.0
# 📦 Copying: swissalti3d_2019_2623-1253_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2623-1260_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2615-1262_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2624-1253_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2620-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2623-1258_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2625-1255_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2625-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2617-1254_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2616-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2617-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2619-1259_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2616-1262_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2622-1264_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2618-1254_2_2056_5728.tif
# ...

# %%
from DEM_processing import extract_relevant_rasters_netCDF_aligned
from DEM_processing import merge_dem_rasters_binput  # or wherever you defined it

# Inputs
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/LIESTAL_DEM_2M/"
output_folder = "/rs_scratch/users/ge24z347/LIESTAL_DEM_2M/LIESTAL"
location_id = 2
square_extent = 10000  # 10 km × 10 km
merged_output_file = "/rs_scratch/users/ge24z347/Liestal_2m/Liestal_2m_DEM.tif"

# Step 1: Extract intersecting tiles and get bbox
bbox = extract_relevant_rasters_netCDF_aligned(
    location_csv=location_csv,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=location_id,
    square_extent=square_extent,
    netcdf_grid_step=1000
)

# Step 2: Merge and crop using that bbox
merge_dem_rasters_binput(
    input_folder=output_folder,
    output_file=merged_output_file,
    bbox=bbox
)
# Out:
# 📏 Snapped NetCDF-aligned extent: 10000.0m × 10000.0m
# 📍 Bounding box: X: 2616000.0 → 2626000.0, Y: 1254000.0 → 1264000.0
# 📦 Copying: swissalti3d_2019_2623-1253_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2623-1260_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2615-1262_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2624-1253_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2620-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2623-1258_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2625-1255_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2625-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2617-1254_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2616-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2617-1263_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2619-1259_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2616-1262_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2622-1264_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2618-1254_2_2056_5728.tif
# ...

# %%
import rasterio

output_file = "/rs_scratch/users/ge24z347/Liestal_2m/Liestal_2m_DEM.tif"

with rasterio.open(output_file) as src:
    bounds = src.bounds
    res_x, res_y = src.res
    width = src.width
    height = src.height

    extent_x = bounds.right - bounds.left
    extent_y = bounds.top - bounds.bottom

    print("📐 DEM Pixel Size:", res_x, "×", res_y)
    print("🗺️  Bounding Box:")
    print(f"   X: {bounds.left} → {bounds.right}  → Width: {extent_x / 1000:.2f} km")
    print(f"   Y: {bounds.bottom} → {bounds.top}  → Height: {extent_y / 1000:.2f} km")
    print("🧮  Dimensions (pixels):", width, "×", height)
# Out:
# 📐 DEM Pixel Size: 2.0 × 2.0
# 🗺️  Bounding Box:
#    X: 2616000.0 → 2626000.0  → Width: 10.00 km
#    Y: 1254000.0 → 1264000.0  → Height: 10.00 km
# 🧮  Dimensions (pixels): 5000 × 5000

# %%
## resampling the dem file to 10 m and 20 m for simulation 
from DEM_processing import DEM_resample_resolution
DEM_resample_resolution(
    input_dem="/rs_scratch/users/ge24z347/Liestal_2m/Liestal_2m_DEM.tif",
    output_dem="/rs_scratch/users/ge24z347/Liestal_20m/Liestal_20m_DEM.tif",
    target_resolution=20,
    resample_method="average"  # Use "bilinear" if "average" isn't supported
)
# Out:
# 📐 Resampling DEM from original to 20 m resolution using 'average'...
# ✅ Resampled DEM saved to: /rs_scratch/users/ge24z347/Liestal_20m/Liestal_20m_DEM.tif

# %%
### GORDEVIO

# %%
#### GORDEVIO 
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/Gordevio_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2701-1120/swissalti3d_2022_2701-1120_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2700-1121/swissalti3d_2022_2700-1121_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2702-1119/swissalti3d_2022_2702-1119_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2700-1119/swissalti3d_2022_2700-1119_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2699-1120/swissalti3d_2022_2699-1120_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2700-1120/swissalti3d_2022_2700-1120_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2699-1119/swissalti3d_2022_2699-1119_2_2056_5728.tif'
# ...

# %%
#### GORDEVIO 
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO"
location_id = 3  # The ID of the target location from the CSV

# **Run Function**
extract_relevant_rasters(
    catchment_shapefile=catchment_shapefile,
    location_csv=location_csv,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=location_id,
    campground_geojson= campground_geojson,
    buffer_distance=100  # Adjust buffer if needed
)
# Out:
# 📦 Copying: swissalti3d_2022_2700-1120_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2701-1120_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2700-1121_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2700-1119_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2701-1119_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2702-1119_2_2056_5728.tif
# ✅ Relevant .tif files saved to /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Gordevio_2m/Gordevio_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2699-1119_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2700-1120_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2699-1121_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2701-1120_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2699-1120_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2700-1121_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2700-1119_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2701-1119_2_2056_5728.tif
# /rs_scratch/users/ge24z347/GORDEVIO_DEM_2M/GORDEVIO/swissalti3d_2022_2702-1119_2_2056_5728.tif
# Merging raster files using GDAL...
# ...

# %%
##### SALAVAUX

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/Salavaux_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2565-1198/swissalti3d_2021_2565-1198_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2565-1199/swissalti3d_2021_2565-1199_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2568-1193/swissalti3d_2021_2568-1193_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2570-1198/swissalti3d_2021_2570-1198_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2571-1195/swissalti3d_2021_2571-1195_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2569-1196/swissalti3d_2021_2569-1196_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2570-1196/swissalti3d_2019_2570-1196_2_2056_5728.tif'
# ...

# %%
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/"  # Folder containing multiple DEM .tif files
campground_geojson = "/rs_scratch/users/ge24z347/addedpolygons_campingsite_391.geojson"
output_folder = "/rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX"
location_id = 4  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=4,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2021_2567-1193_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2571-1193_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2571-1195_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1194_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2570-1195_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2567-1194_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2570-1194_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2567-1197_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2569-1193_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2571-1197_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2570-1193_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2570-1196_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1195_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1196_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1193_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2571-1196_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2567-1196_2_2056_5728.tif
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Salavaux_2m/Salavaux_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2567-1193_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2571-1193_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2571-1195_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2568-1194_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2570-1195_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2567-1194_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2570-1194_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2567-1197_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SALAVAUX_DEM_2M/SALAVAUX/swissalti3d_2021_2569-1193_2_2056_5728.tif
# ...

# %%
### BUOCHS

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/BUOCHS_DEM_2M/Buochs_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/BUOCHS_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2674-1202/swissalti3d_2022_2674-1202_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2673-1202/swissalti3d_2022_2673-1202_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2672-1204/swissalti3d_2022_2672-1204_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2673-1203/swissalti3d_2022_2673-1203_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2675-1203/swissalti3d_2022_2675-1203_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2674-1203/swissalti3d_2022_2674-1203_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2674-1204/swissalti3d_2022_2674-1204_2_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/BUOCHS_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS"
location_id = 5  # The ID of the target location from the CSV
campground_geojson = "/rs_scratch/users/ge24z347/addedpolygons_campingsite_391.geojson"


extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=5,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2022_2672-1204_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2675-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2674-1204_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2673-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2676-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2675-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2673-1204_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2675-1204_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2674-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2674-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2672-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2673-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2672-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2676-1202_2_2056_5728.tif
# ✅ Extracted relevant rasters saved to: /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Buochs_2m/Buochs_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2672-1204_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2675-1203_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2674-1204_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2673-1203_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2676-1203_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2675-1202_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2673-1204_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2675-1204_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2674-1202_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BUOCHS_DEM_2M/BUOCHS/swissalti3d_2022_2674-1203_2_2056_5728.tif
# ...

# %%
######## SEMPACH

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/SEMPACH_DEM_2M/Sempach_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/SEMPACH_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2658-1221/swissalti3d_2022_2658-1221_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2658-1220/swissalti3d_2022_2658-1220_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2664-1214/swissalti3d_2022_2664-1214_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2665-1219/swissalti3d_2022_2665-1219_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2665-1214/swissalti3d_2022_2665-1214_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2657-1223/swissalti3d_2022_2657-1223_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2662-1214/swissalti3d_2022_2662-1214_2_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/SEMPACH_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH"
location_id = 6  # The ID of the target location from the CSV
campground_geojson = "/rs_scratch/users/ge24z347/addedpolygons_campingsite_391.geojson"

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=6,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2022_2656-1219_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2657-1217_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2658-1217_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2657-1221_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2656-1218_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2655-1219_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2657-1220_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2658-1220_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2658-1221_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2654-1220_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2655-1218_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2655-1217_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2658-1219_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2654-1219_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2655-1220_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2654-1221_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2656-1221_2_2056_5728.tif
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Sempach_2m/Sempach_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2656-1219_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2657-1217_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2658-1217_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2657-1221_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2656-1218_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2655-1219_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2657-1220_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2658-1220_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2658-1221_2_2056_5728.tif
# /rs_scratch/users/ge24z347/SEMPACH_DEM_2M/SEMPACH/swissalti3d_2022_2654-1220_2_2056_5728.tif
# ...

# %%
#####INTERLAKEN

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/Interlaken_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2633-1172/swissalti3d_2019_2633-1172_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2622-1175/swissalti3d_2019_2622-1175_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2630-1172/swissalti3d_2019_2630-1172_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2623-1164/swissalti3d_2019_2623-1164_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2626-1165/swissalti3d_2019_2626-1165_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2621-1170/swissalti3d_2019_2621-1170_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2632-1173/swissalti3d_2019_2632-1173_2_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN"
campground_geojson = "/rs_scratch/users/ge24z347/addedpolygons_campingsite_391.geojson"
location_id = 7  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=7,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2019_2628-1170_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2628-1169_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2629-1167_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2630-1170_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2627-1171_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2628-1167_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2627-1169_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2626-1167_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2626-1171_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2629-1168_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2626-1170_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2626-1168_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2630-1171_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2627-1168_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2627-1170_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2630-1169_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2630-1167_2_2056_5728.tif
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Interlaken_2m/Interlaken_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2632-1168_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2626-1172_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2628-1170_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2627-1166_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2629-1166_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2632-1169_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2632-1172_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2626-1166_2_2056_5728.tif
# /rs_scratch/users/ge24z347/INTERLAKEN_DEM_2M/INTERLAKEN/swissalti3d_2019_2628-1169_2_2056_5728.tif
# ...

# %%
#### AAREGG

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/AAREGG_DEM_2M/Aaregg_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/AAREGG_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2645-1178/swissalti3d_2019_2645-1178_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2647-1178/swissalti3d_2019_2647-1178_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2647-1176/swissalti3d_2019_2647-1176_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2646-1177/swissalti3d_2019_2646-1177_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2647-1177/swissalti3d_2019_2647-1177_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2646-1176/swissalti3d_2019_2646-1176_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2646-1178/swissalti3d_2019_2646-1178_2_2056_5728.tif'
# Total unique URLs found: 7
# CSV Content Preview:
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/AAREGG_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG"
location_id = 8  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=8,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2019_2647-1176_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2646-1177_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2647-1177_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2646-1178_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2645-1178_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2646-1176_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2647-1178_2_2056_5728.tif
# ✅ Extracted relevant rasters saved to: /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Aaregg_2m/Interlaken_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2647-1176_2_2056_5728.tif
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2646-1177_2_2056_5728.tif
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2647-1177_2_2056_5728.tif
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2646-1178_2_2056_5728.tif
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2645-1178_2_2056_5728.tif
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2646-1176_2_2056_5728.tif
# /rs_scratch/users/ge24z347/AAREGG_DEM_2M/AAREGG/swissalti3d_2019_2647-1178_2_2056_5728.tif
# Merging raster files using GDAL...
# Merged DEM saved to: /rs_scratch/users/ge24z347/Aaregg_2m/Interlaken_2m_DEM.tif

# %%
##### BERN

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/BERN_DEM_2M/Bern_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/BERN_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2595-1202/swissalti3d_2019_2595-1202_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2594-1201/swissalti3d_2019_2594-1201_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2593-1201/swissalti3d_2019_2593-1201_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2593-1202/swissalti3d_2019_2593-1202_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2594-1203/swissalti3d_2019_2594-1203_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2596-1201/swissalti3d_2019_2596-1201_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2596-1202/swissalti3d_2019_2596-1202_2_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/BERN_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/BERN_DEM_2M/BERN"
location_id = 9  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=9,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2019_2594-1201_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2596-1201_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2595-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2593-1201_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2593-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2593-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2597-1201_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2594-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2594-1203_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2596-1202_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2595-1201_2_2056_5728.tif
# ✅ Extracted relevant rasters saved to: /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/BERN_DEM_2M/BERN"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Bern_2m/Bern_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2594-1201_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2596-1201_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2595-1202_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2593-1201_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2593-1202_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2593-1203_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2597-1201_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2594-1202_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2594-1203_2_2056_5728.tif
# /rs_scratch/users/ge24z347/BERN_DEM_2M/BERN/swissalti3d_2019_2596-1202_2_2056_5728.tif
# ...

# %%
### NEUCHATEL LA TENE

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/Neuchatel_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2568-1206/swissalti3d_2021_2568-1206_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2566-1206/swissalti3d_2021_2566-1206_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2568-1205/swissalti3d_2021_2568-1205_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2567-1206/swissalti3d_2021_2567-1206_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2566-1205/swissalti3d_2021_2566-1205_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2566-1207/swissalti3d_2021_2566-1207_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2567-1205/swissalti3d_2021_2567-1205_2_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL"
location_id = 10  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=10,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2019_2567-1204_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1206_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2566-1207_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2567-1206_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2566-1205_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1205_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2567-1207_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2566-1206_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2567-1205_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2568-1207_2_2056_5728.tif
# ✅ Extracted relevant rasters saved to: /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Neuchatel/Neuchatel_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2019_2567-1204_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2568-1206_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2566-1207_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2567-1206_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2566-1205_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2568-1205_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2567-1207_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2566-1206_2_2056_5728.tif
# /rs_scratch/users/ge24z347/NEUCHATEL_DEM_2M/NEUCHATEL/swissalti3d_2021_2567-1205_2_2056_5728.tif
# ...

# %%
## MUZZANO

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/LUGANO_DEM_2M/Lugano_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/LUGANO_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2712-1094/swissalti3d_2022_2712-1094_0.5_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2712-1093/swissalti3d_2022_2712-1093_0.5_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2711-1093/swissalti3d_2022_2711-1093_0.5_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2711-1094/swissalti3d_2022_2711-1094_0.5_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2714-1094/swissalti3d_2022_2714-1094_0.5_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2714-1095/swissalti3d_2022_2714-1095_0.5_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2022_2715-1095/swissalti3d_2022_2715-1095_0.5_2056_5728.tif'
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/MUZZANO_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO"
location_id = 11  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=11,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2022_2712-1094_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2712-1095_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2714-1094_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2714-1096_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2712-1096_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2713-1096_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2715-1095_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2715-1093_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2714-1095_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2714-1093_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2713-1095_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2713-1094_2_2056_5728.tif
# 📦 Copying: swissalti3d_2022_2715-1094_2_2056_5728.tif
# ✅ Extracted relevant rasters saved to: /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Muzzano_2m/Muzzano_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2712-1094_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2712-1095_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2714-1094_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2714-1096_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2712-1096_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2713-1096_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2715-1095_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2715-1093_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2714-1095_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MUZZANO_DEM_2M/MUZZANO/swissalti3d_2022_2714-1093_2_2056_5728.tif
# ...

# %%
## WERDENBERG

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/Werdenberg_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2020_2753-1225/swissalti3d_2020_2753-1225_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2020_2753-1226/swissalti3d_2020_2753-1226_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2020_2752-1226/swissalti3d_2020_2752-1226_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2020_2752-1224/swissalti3d_2020_2752-1224_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2020_2753-1224/swissalti3d_2020_2753-1224_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2019_2752-1225/swissalti3d_2019_2752-1225_2_2056_5728.tif'
# Total unique URLs found: 6
# CSV Content Preview:
#                                                    0
# 0  https://data.geo.admin.ch/ch.swisstopo.swissal...
# 1  https://data.geo.admin.ch/ch.swisstopo.swissal...
# ...

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG"
location_id = 12  # The ID of the target location from the CSV

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=12,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2020_2752-1224_2_2056_5728.tif
# 📦 Copying: swissalti3d_2020_2753-1224_2_2056_5728.tif
# 📦 Copying: swissalti3d_2020_2753-1226_2_2056_5728.tif
# 📦 Copying: swissalti3d_2020_2753-1225_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2752-1225_2_2056_5728.tif
# 📦 Copying: swissalti3d_2020_2752-1226_2_2056_5728.tif
# ✅ Extracted relevant rasters saved to: /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Werdenberg_2m/Werdenberg_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG/swissalti3d_2020_2752-1224_2_2056_5728.tif
# /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG/swissalti3d_2020_2753-1224_2_2056_5728.tif
# /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG/swissalti3d_2020_2753-1226_2_2056_5728.tif
# /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG/swissalti3d_2020_2753-1225_2_2056_5728.tif
# /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG/swissalti3d_2019_2752-1225_2_2056_5728.tif
# /rs_scratch/users/ge24z347/WERDENBERG_DEM_2M/WERDENBERG/swissalti3d_2020_2752-1226_2_2056_5728.tif
# Merging raster files using GDAL...
# Merged DEM saved to: /rs_scratch/users/ge24z347/Werdenberg_2m/Werdenberg_2m_DEM.tif

# %%
## MORGES

# %%
# Define the CSV file location (Update this path)
csv_file_path = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/Morges_2m.csv"

# Define the output directory where files will be saved
output_directory = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/"

# Call the function
download_from_csvfile(csv_file=csv_file_path, output_dir=output_directory)
# Out:
# Unique URLs in CSV:
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2513-1155/swissalti3d_2021_2513-1155_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2514-1158/swissalti3d_2021_2514-1158_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2523-1159/swissalti3d_2021_2523-1159_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2532-1177/swissalti3d_2021_2532-1177_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2529-1151/swissalti3d_2021_2529-1151_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2541-1154/swissalti3d_2021_2541-1154_2_2056_5728.tif'
# 'https://data.geo.admin.ch/ch.swisstopo.swissalti3d/swissalti3d_2021_2528-1153/swissalti3d_2021_2528-1153_2_2056_5728.tif'
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/Morges_2m_DEM_fulldomain.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       3 output_file = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/Morges_2m_DEM_fulldomain.tif"  # Output merged DEM file
#       5 # **Run Function**
# ----> 6 merge_dem_rasters(
#       7     input_folder=input_folder,
#       8     output_file=output_file
#       9 )
#
# TypeError: merge_dem_rasters() missing 1 required positional argument: 'bounds'

# %%
###### Find the most important raster files for Zell Catchment 
# **Define Inputs**
catchment_shapefile = "/rs_scratch/users/ge24z347/geo_ezgg_2km_ge.shp"
location_csv = "/rs_scratch/users/ge24z347/catchment_location.csv"
dem_folder = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/"  # Folder containing multiple DEM .tif files
output_folder = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES"
location_id = 13  # The ID of the target location from the CSV
campground_geojson = "/rs_scratch/users/ge24z347/addedpolygons_campingsite_391.geojson"

extract_rasters_near_campground(
    location_csv=location_csv,
    campground_geojson=campground_geojson,
    dem_folder=dem_folder,
    output_folder=output_folder,
    location_id=13,              # Match ID from CSV
    half_extent=2000              # 2 km each side = 4 km square
)
# Out:
# 📦 Copying: swissalti3d_2021_2528-1152_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2528-1151_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2527-1150_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2529-1151_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2527-1151_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2525-1150_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2528-1148_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2529-1150_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2529-1148_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2528-1149_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2525-1148_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2526-1148_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2529-1152_2_2056_5728.tif
# 📦 Copying: swissalti3d_2019_2527-1149_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2525-1152_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2526-1152_2_2056_5728.tif
# 📦 Copying: swissalti3d_2021_2526-1149_2_2056_5728.tif
# ...

# %%
# **Define Inputs**
input_folder = "/rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES"  # Folder containing multiple .tif DEMs
output_file = "/rs_scratch/users/ge24z347/Morges_2m/Morges_2m_DEM.tif"  # Output merged DEM file

# **Run Function**
merge_dem_rasters(
    input_folder=input_folder,
    output_file=output_file
)
# Out:
# Relevant .tif files for merging:
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2021_2528-1152_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2021_2528-1151_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2021_2527-1150_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2021_2529-1151_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2021_2527-1151_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2021_2525-1150_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2019_2528-1148_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2019_2529-1150_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2019_2529-1148_2_2056_5728.tif
# /rs_scratch/users/ge24z347/MORGES_DEM_2M/MORGES/swissalti3d_2019_2528-1149_2_2056_5728.tif
# ...
