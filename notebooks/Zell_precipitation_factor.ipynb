# %%
#### precipitation factor with the 100% of the precipitation

# %%
import xarray as xr
import numpy as np

f1  = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Zell_2m_accv1/Zell_2m_accv1.nc"
f08 = "/storage/homefs/ge24z347/LISFLOOD_FP_8_1/build/Zell_2m_accv14/Zell_2m_accv14.nc"

ds1  = xr.open_dataset(f1)
ds08 = xr.open_dataset(f08)

a1  = ds1["rainfall_depth"].isel(time=7).values
a08 = ds08["rainfall_depth"].isel(time=7).values

print("t7 max f1 :", np.nanmax(a1))
print("t7 max f0.8:", np.nanmax(a08))
print("ratio (should be 0.8):", np.nanmax(a08)/np.nanmax(a1))

print("Any weird huge values in f0.8?:", np.nanmax(ds08["rainfall_depth"].values))
# Out:
# t7 max f1 : 8.258006
# t7 max f0.8: 6.606405
# ratio (should be 0.8): 0.8
# Any weird huge values in f0.8?: 35.751842
